# %% [markdown]
# <a href="https://colab.research.google.com/github/wendyxie6/python-learning-journal/blob/main/quiz3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Pets:
    def __init__(self, name, species, hunger, fun):
        self.name = name
        self.species = species
        self.hunger = hunger
        self.fun = fun

    def update(self, hours):
        raise NotImplementedError

    def printInfo(self):
        raise NotImplementedError

class Dog(Pets):
    def __init__(self, name, species, hunger, fun):
        super(). __init__(name, species, hunger, fun)

    def update(self):
        self.hunger = input("Enter dog new hours: ")

        return self.hunger

    def printInfo(self):
        print(f"Dog name: {self.name} Species: {self.species} Hunger: {self.hunger} Fun: {self.fun}")

class Cat(Pets):
    def __init__(self, name, species, hunger, fun):
        super(). __init__(name, species, hunger, fun)

    def update(self):
        self.fun = input("Enter cat new hours: ")

        return self.fun

    def printInfo(self):
        print(f"Cat name: {self.name} Species: {self.species} Hunger: {self.hunger} Fun: {self.fun}")

class Owner:
    def __init__(self, name, dog, cat):
        self.name = name
        self.dog = dog
        self.cat = cat

    def printAllPets(self, pet1, pet2):
        print(f"The owner {self.name} has a dog: {pet1.name} and a cat: {pet2.name}")


    def feedPet(self, pet):
        print(f"{self.name} feed {pet.name} at {pet.hunger}")

    def playWithPet(self, pet):
        print(f"{self.name} play with {pet.name} at {pet.hunger}")


pet1 = Dog("Doggy", "dog", "10:30", "14:00")
pet2 = Cat("Kitty", "cat", "12:00", "15:30")

owner = Owner("Jane Doe", pet1, pet2)

# Display owner info
owner.printAllPets(pet1, pet2)

#update Dog feed time
pet1.hunger = Dog.update(pet1)

# print dog updated info
pet1.printInfo()


# update cat fun time
pet2.fun = Cat.update(pet2)

# print dog updated info
pet2.printInfo()

# print owner feed pet time
owner.feedPet(pet1)
owner.feedPet(pet2)

# print owner play with pet time
owner.playWithPet(pet1)
owner.playWithPet(pet2)
# Out:
# The owner Jane Doe has a dog: Doggy and a cat: Kitty
# Enter dog new hours: 3:00
# Dog name: Doggy Species: dog Hunger: 3:00 Fun: 14:00
# Enter cat new hours: 2:00
# Cat name: Kitty Species: cat Hunger: 12:00 Fun: 2:00
# Jane Doe feed Doggy at 3:00
# Jane Doe feed Kitty at 12:00
# Jane Doe play with Doggy at 3:00
# Jane Doe play with Kitty at 12:00
