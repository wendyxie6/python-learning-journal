# %% [markdown]
# <a href="https://colab.research.google.com/github/wendyxie6/python-learning-journal/blob/main/Copy_of_leture11_abstract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Player:
    def __init__(self, name, jerseyNum, height, injuries):
        self.name = name
        self.jerseyNum = jerseyNum
        self.height = height
        self.injures = injures

    def play(self):
        raise NotImplementedError

class Quarterback(Player):
    def __init__(self, name, jerseyNum, height, injuries, yardsThrown):
        super().__init__(name, jerseyNum, height, injuries)
        self.yardsThrown = yardsThrown

    def play(self):
        print("Take snap throw ball!")

class Pitcher(Player):
    def __init__(self, name, jerseyNum, height, injuries, strikeouts):
        super().__init__(name, jerseyNum, height, injuriese)
        self.strikeouts = strikeouts

    def play(self):
        print("consider and throw ball")


aR = Quarterback("Aaron Rodgers", 8, 6.2, 250, None, 2000)
sohei = Pitcher("Shohei Otani", -1, 4.9, 250, , , 100)

team = [aR, sohei]

for guy in team:
    print(f"{guy.name} get on to the court")
    guy.play()
# Out:
#   File "/tmp/ipython-input-1199510651.py", line 29
#     sohei = Pitcher("Shohei Otani", -1, 4.9, 250, , , 100)
#                                                   ^
# SyntaxError: invalid syntax
