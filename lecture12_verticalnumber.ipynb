# %% [markdown]
# <a href="https://colab.research.google.com/github/wendyxie6/python-learning-journal/blob/main/lecture12_verticalnumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def writeVertical(num):
    if num < 10:
        print(num)
    else:
        writeVertical(num//10)
        print(num % 10)

writeVertical(1234)
# Out:
# 1
# 2
# 3
# 4
