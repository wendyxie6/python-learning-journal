# %% [markdown]
# <a href="https://colab.research.google.com/github/wendyxie6/python-learning-journal/blob/main/Pandas_GroupBy_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Load Data**
# Load the same MPG dataset

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# DO NOT RUN THIS
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ## **Choosing the Right Categorical Column**
#
# **Question:**
# Which column would you use to analyze how fuel efficiency changes over time, and how can you verify the distinct values and their frequencies?

# %%
model_array = df.loc[df['model_year']>0, 'model_year'].unique()
model_array.sort()
model_array
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
# DO NOT RUN THIS
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
df.groupby('model_year').value_counts
# Out:
# <bound method DataFrameGroupBy.value_counts of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x78c40c1f64b0>>

# %%
# DO NOT RUN THIS
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 80    29
# 79    29
# 81    29
# 70    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %% [markdown]
# ## **GroupBy with a Single Column**
#
# **Question:**
# What is the average value of all numeric variables for each model year?

# %%
# DO NOT RUN THIS
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %% [markdown]
# ## **Accessing Specific Results**
#
# **Question:**
# After computing the grouped averages, how can you inspect the index, available columns, and extract only the average MPG?

# %%
# DO NOT RUN THIS
# Out:
# Index([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype='int64', name='model_year')

# %%
# DO NOT RUN THIS
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'origin'], dtype='object')

# %%
# DO NOT RUN THIS
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %% [markdown]
# **Question:** How can you compute the average MPG per model year in a single line of code?

# %%
# DO NOT RUN THIS
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %% [markdown]
# **Question:**
# How can you view detailed summary statistics (count, mean, std, min, max, percentiles) for each model year?

# %%
# DO NOT RUN THIS
# Out:
#              mpg                                                          \
#            count       mean       std   min     25%    50%     75%   max
# model_year
# 70          29.0  17.689655  5.339231   9.0  14.000  16.00  22.000  27.0
# 71          28.0  21.250000  6.591942  12.0  15.500  19.00  27.000  35.0
# 72          28.0  18.714286  5.435529  11.0  13.750  18.50  23.000  28.0
# 73          40.0  17.100000  4.700245  11.0  13.000  16.00  20.000  29.0
# 74          27.0  22.703704  6.420010  13.0  16.000  24.00  27.000  32.0
# 75          30.0  20.266667  4.940566  13.0  16.000  19.50  23.000  33.0
# 76          34.0  21.573529  5.889297  13.0  16.750  21.00  26.375  33.0
# 77          28.0  23.375000  6.675862  15.0  17.375  21.75  30.000  36.0
# 78          36.0  24.061111  6.898044  16.2  19.350  20.70  28.000  43.1
# 79          29.0  25.093103  6.794217  15.5  19.200  23.90  31.800  37.3
# 80          29.0  33.696552  7.037983  19.1  29.800  32.70  38.100  46.6
# ...

# %% [markdown]
# <br> <br> <br>

# %% [markdown]
# # **Grouping by Multiple Columns (MultiIndex)**

# %% [markdown]
# **Question:**
# How does the average fuel efficiency vary by both model year and number of cylinders?

# %%
# DO NOT RUN THIS
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %% [markdown]
# **Question:**
# After grouping by model year and cylinders, how can you inspect the structure and levels of the resulting MultiIndex?

# %%
# DO NOT RUN THIS
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
# DO NOT RUN THIS
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
# DO NOT RUN THIS
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %% [markdown]
# **Question:**
# How can you select all grouped results for a single model year? e.g. 70

# %%
# DO NOT RUN THIS
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %% [markdown]
# **Question:**
# How can you select grouped results for multiple model years?

# %%
# DO NOT RUN THIS
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 82         4          32.071429    118.571429  2402.321429     16.703571
#            6          28.333333    225.000000  2931.666667     16.033333
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 82         4          1.714286
#            6          1.000000

# %% [markdown]
# **Question:**
# How can you select data for a specific model year and cylinder count?

# %%
# DO NOT RUN THIS
# Out:
# mpg               14.111111
# displacement     367.555556
# weight          3940.055556
# acceleration      11.194444
# origin             1.000000
# Name: (70, 8), dtype: float64

# %% [markdown]
# **Question:**
# How can you sort the MultiIndex by model year in descending order?

# %%
# DO NOT RUN THIS
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         8          18.630000    321.400000  3862.900000     15.400000
#            6          22.950000    205.666667  3025.833333     15.433333
# ...

# %% [markdown]
# # **Advanced Aggregation with agg()**
#
# **Question:**
# How can you compute multiple aggregate statistics for all numeric columns in the DataFrame?

# %%
# DO NOT RUN THIS
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# mean    23.514573   5.454774    193.425879  104.469388  2970.424623
# median  23.000000   4.000000    148.500000   93.500000  2803.500000
#
#         acceleration  model_year    origin
# mean        15.56809    76.01005  1.572864
# median      15.50000    76.00000  1.000000

# %% [markdown]
# **Question:**
# How can you compute the sum and mean only for the MPG and weight columns?

# %%
# DO NOT RUN THIS
# Out:
#               mpg        weight
# sum   9358.800000  1.182229e+06
# mean    23.514573  2.970425e+03

# %% [markdown]
# **Question:**
# How can you apply different aggregation functions to different columns?

# %%
# DO NOT RUN THIS
# Out:
#               mpg       weight
# mean    23.514573  2970.424623
# median  23.000000          NaN
# std           NaN   846.841774

# %% [markdown]
# **Question:**
# How can you apply different aggregation functions per column after grouping by model year?

# %%
# DO NOT RUN THIS
# Out:
#                   mpg              weight
#                  mean median         mean          std
# model_year
# 70          17.689655  16.00  3372.793103   852.868663
# 71          21.250000  19.00  2995.428571  1061.830859
# 72          18.714286  18.50  3237.714286   974.520960
# 73          17.100000  16.00  3419.025000   974.809133
# 74          22.703704  24.00  2877.925926   949.308571
# 75          20.266667  19.50  3176.800000   765.179781
# 76          21.573529  21.00  3078.735294   821.371481
# 77          23.375000  21.75  2997.357143   912.825902
# 78          24.061111  20.70  2861.805556   626.023907
# 79          25.093103  23.90  3055.344828   747.881497
# 80          33.696552  32.70  2436.655172   432.235491
# 81          30.334483  31.60  2522.931034   533.600501
# 82          31.709677  32.00  2453.548387   354.276713
