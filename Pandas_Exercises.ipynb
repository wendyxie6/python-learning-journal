# %% [markdown]
# <a href="https://colab.research.google.com/github/wendyxie6/python-learning-journal/blob/main/Pandas_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas Practice Exercises — Hotel Booking Dataset**
#
# These exercises use the **hotel booking dataset** to practice core Pandas skills.
# Follow the steps **in order**. Do not skip steps.

# %% [markdown]
# ## **Step 0 — Setup & Dataset Loading**
#
# ### Exercise 0.1
# Import the required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Exercise 0.2
# Load the dataset:
# - File name: `hotel_booking_data.csv`
# - Store it in a DataFrame called `df`

# %%
df = pd.read_csv('hotel_booking_data.csv')
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %% [markdown]
# Display:
# - The **first 5 rows**
# - The **last 5 rows**

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ## **Step 1 — Understanding the Data**
#
# ### Exercise 1.1
# Check the **shape** of the dataset.
# - How many rows?
# - How many columns?

# %%
print(f"Number of rows: {len(df)}")
print(f"Number of columns: {len(df.columns)}")
# Out:
# Number of rows: 119390
# Number of columns: 36

# %% [markdown]
# ### Exercise 1.2
# Display:
# - Column names
# - Data types of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ### Exercise 1.3
# Use `.info()` to answer:
# - Which columns contain missing values?
# - How many non-null values exist per column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ### Exercise 1.4
# Use `.describe()` on **numerical columns**.
# - What is the average `lead_time`?
# - What is the maximum number of `adults`?

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## **Step 2 — Selecting Data (Indexing & Columns)**
#
# ### Exercise 2.1
# Select and display **only** the following columns:
# - `hotel`
# - `lead_time`
# - `adr`
# - `is_canceled`

# %%
df[['hotel', 'lead_time', 'adr', 'is_canceled']]
# Out:
#                hotel  lead_time     adr  is_canceled
# 0       Resort Hotel        342    0.00            0
# 1       Resort Hotel        737    0.00            0
# 2       Resort Hotel          7   75.00            0
# 3       Resort Hotel         13   75.00            0
# 4       Resort Hotel         14   98.00            0
# ...              ...        ...     ...          ...
# 119385    City Hotel         23   96.14            0
# 119386    City Hotel        102  225.43            0
# 119387    City Hotel         34  157.71            0
# 119388    City Hotel        109  104.40            0
# 119389    City Hotel        205  151.20            0
#
# [119390 rows x 4 columns]

# %% [markdown]
# ### Exercise 2.2
# Select a **single column** (`adr`) and:
# - Check its data type
# - Display its first 10 values

# %%
df['adr'].dtype
df['adr'].head(10)
# Out:
# 0      0.0
# 1      0.0
# 2     75.0
# 3     75.0
# 4     98.0
# 5     98.0
# 6    107.0
# 7    103.0
# 8     82.0
# 9    105.5
# Name: adr, dtype: float64

# %% [markdown]
# ### Exercise 2.3
# Select rows:
# - Rows 0 through 9
# - Rows 100 through 110

# %%
table1 = df.iloc[0:10]
table2 = df.iloc[100:111]

table = pd.concat([table1, table2])

table
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 0    Resort Hotel            0        342               2015
# 1    Resort Hotel            0        737               2015
# 2    Resort Hotel            0          7               2015
# 3    Resort Hotel            0         13               2015
# 4    Resort Hotel            0         14               2015
# 5    Resort Hotel            0         14               2015
# 6    Resort Hotel            0          0               2015
# 7    Resort Hotel            0          9               2015
# 8    Resort Hotel            1         85               2015
# 9    Resort Hotel            1         75               2015
# 100  Resort Hotel            0          4               2015
# 101  Resort Hotel            0         98               2015
# 102  Resort Hotel            0         92               2015
# 103  Resort Hotel            0         95               2015
# ...

# %% [markdown]
# ## **Step 3 — Filtering Rows (Boolean Indexing)**
#
# ### Exercise 3.1
# Filter bookings where:
# - `hotel` is `"Resort Hotel"`

# %%
df[df['hotel'] == 'Resort Hotel']
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %% [markdown]
# ### Exercise 3.2
# Filter bookings where:
# - `is_canceled == 1`
#
# How many canceled bookings are there?

# %%
df[df['is_canceled'] == 1]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %% [markdown]
# ### Exercise 3.3
# Filter bookings where:
# - `adr` is greater than 150

# %%
df[df['adr'] >150]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 13      Resort Hotel            0         18               2015
# 19      Resort Hotel            0          7               2015
# 45      Resort Hotel            1         47               2015
# 65      Resort Hotel            0         10               2015
# 97      Resort Hotel            0         63               2015
# ...              ...          ...        ...                ...
# 119379    City Hotel            0        109               2017
# 119382    City Hotel            0        135               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 13                   July                        27
# 19                   July                        27
# ...

# %% [markdown]
# ### Exercise 3.4
# Filter bookings where:
# - `hotel` is `"City Hotel"`
# - AND `is_canceled == 0`

# %%
flt = df[(df['hotel'] == 'City Hotel') & (df['is_canceled'] == 0)]
flt
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40066   City Hotel            0          3               2015
# 40070   City Hotel            0         43               2015
# 40071   City Hotel            0         43               2015
# 40072   City Hotel            0         43               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40066                July                        27
# 40070                July                        27
# ...

# %% [markdown]
# ## **Step 4 — Creating & Modifying Columns**
#
# ### Exercise 4.1
# Create a new column called:
# - `total_guests`
#
# It should be the sum of:
# - `adults`
# - `children`
# - `babies`

# %%
df['total_guests'] = df['adults'] + df['children'] + df['babies']
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# ### Exercise 4.2
# Create a column called:
# - `is_family`
#
# Set it to:
# - `True` if `children > 0` OR `babies > 0`
# - `False` otherwise

# %%
df['is_family'] = (df['children'] > 0) | (df['babies'] >0)
df['children'] = df['children'].fillna(0)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# ### Exercise 4.3
# Verify your changes:
# - Display the first 5 rows including the new columns

# %%
family = df[df['is_family'] == True][['hotel', 'adr', 'total_guests', 'is_family']]
family
# Out:
#                hotel     adr  total_guests  is_family
# 13      Resort Hotel  154.77           3.0       True
# 45      Resort Hotel  153.00           4.0       True
# 55      Resort Hotel  107.00           4.0       True
# 65      Resort Hotel  153.00           4.0       True
# 87      Resort Hotel  108.73           3.0       True
# ...              ...     ...           ...        ...
# 119270    City Hotel  135.00           3.0       True
# 119287    City Hotel  177.75           3.0       True
# 119293    City Hotel  189.00           4.0       True
# 119318    City Hotel  153.90           3.0       True
# 119319    City Hotel  194.13           4.0       True
#
# [9332 rows x 4 columns]
